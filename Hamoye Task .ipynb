# %% [markdown]
# # HAMOYE STAGE ONE TASK

# %% [markdown]
# # Question 1
# If you’re given two lists: A = [1,2,3,4,5,6] B = [13, 21, 34]
#
# The task is to create a list with the elements of A and B in a single dimension with output: A_B = [1,2,3,4,5,6,13, 21, 34]
#
# Which of the following option is the best way to create this list?

# %%
A = [1,2,3,4,5,6]
B = [13,21,34]

# %%
A.extend(B)
print(A)
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]

# %% [markdown]
# # Question 2
# How do you create an identity matrix in python?
# ANSWER => np.identity(3)

# %%
import numpy as np
np.identity(3)
# Out:
# array([[ 1.,  0.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0.,  0.,  1.]])

# %% [markdown]
# # Question 3
# Which of the following fuel type code has the lowest average fuel cost per unit burned?
# Answer => Gas

# %%
import pandas as pd
url='https://github.com/WalePhenomenon/climate_change/blob/master/fuel_ferc1.csv?raw=true'
fuel_data = pd.read_csv(url, error_bad_lines=False)
fuel_data
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# 6         f1_fuel_1994_12_2_1_1                 2         1994
# 7        f1_fuel_1994_12_2_1_10                 2         1994
# 8        f1_fuel_1994_12_2_2_10                 2         1994
# 9         f1_fuel_1994_12_4_0_1                 4         1994
# 10        f1_fuel_1994_12_4_0_2                 4         1994
# 11        f1_fuel_1994_12_4_0_4                 4         1994
# 12        f1_fuel_1994_12_4_0_5                 4         1994
# 13        f1_fuel_1994_12_6_0_1                 6         1994
# ...

# %%
a= fuel_data.groupby('fuel_type_code_pudl')['fuel_cost_per_unit_burned'].mean()
a.sort_values(ascending=True)
# Out:
# fuel_type_code_pudl
# gas          13.659397
# other        18.253856
# waste        19.518122
# coal         67.421830
# oil         168.877086
# nuclear    4955.157002
# Name: fuel_cost_per_unit_burned, dtype: float64

# %% [markdown]
# # Question 4
# What is the standard deviation and 75th percentile of the measure of energy per unit (Fuel_mmbtu_per_unit) in two decimal places?
# Answer => 10.60 and 17.01

# %%
fuel_data['fuel_mmbtu_per_unit'].describe(include=all)
# Out:
# count    29523.000000
# mean         8.492111
# std         10.600220
# min          0.000001
# 25%          1.024000
# 50%          5.762694
# 75%         17.006000
# max        341.260000
# Name: fuel_mmbtu_per_unit, dtype: float64

# %% [markdown]
# # Question 5
#
# What is the skewness and kurtosis for the fuel quantity burned in two decimal places?
#
# Answer => 15.85 and 651.37

# %%
fuel_data['fuel_qty_burned'].skew()
# Out:
# 15.851495469109503

# %%
fuel_data["fuel_qty_burned"].kurtosis()
# Out:
# 651.36945013377317

# %% [markdown]
# # Question 6
#
# Which feature has missing values and what is the total number of missing value and percentage of the missing rows as a factor of the total number of rows in three decimal places? (Enter answer in the format: Feature: xxx, Total: xxx, Percent: xxx)
#
# Answer => Feature:fuel_unit,Total: 180,Percent: 0.609

# %%
number_of_row = fuel_data.shape[0]
number_of_row
# Out:
# 29523

# %%
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
round(((180/29523)*100),3)
# Out:
# 0.61

# %% [markdown]
# # Question 7
# The feature with missing values falls under what category? What missing value imputation technique would you use?

# %%
fuel_data[['fuel_unit']] = fuel_data[['fuel_unit']].fillna(value='mcf')

# %%
fuel_data["fuel_unit"].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Question 8
#
# Which of the features has the second and third lowest correlation with the Fuel Cost Per Unit Burned?
#
# Answer => fuel_qty_burned and fuel_mmbtu_per_unit

# %%
d = fuel_data.corrwith(fuel_data['fuel_cost_per_unit_burned'])
d.sort_values(ascending=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-f483d4372366> in <module>()
# ----> 1 d = fuel_data.corrwith(fuel_data['fuel_cost_per_unit_burned'])
#       2 d.sort_values(ascending=True)
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in corrwith(self, other, axis, drop)
#    4927         axis = self._get_axis_number(axis)
#    4928         if isinstance(other, Series):
# -> 4929             return self.apply(other.corr, axis=axis)
#    4930
#    4931         this = self._get_numeric_data()
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
# ...

# %% [markdown]
# # Question 9
#
# For the fuel type coal, what is the percentage change in the fuel cost per unit burned in 1998 compared to 1994?
# Answer => none of the above

# %%
fuel_data.groupby('report_year')['fuel_cost_per_unit_burned'].mean().head()

# %% [markdown]
# # Question 10
# Which year has the highest average fuel cost per unit delivered?
#
# Answer => 1997

# %%
e= fuel_data.groupby('report_year')['fuel_cost_per_unit_delivered'].mean()
e.sort_values(ascending=False).head()
